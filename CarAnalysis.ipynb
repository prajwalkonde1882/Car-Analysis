# %%
import pandas as pd
import matplotlib as plb
import numpy as py
import seaborn as sb

# %% [markdown]
# # pandas

# %% [markdown]
# 1.Required for working on Data Set

# %% [markdown]
# 2.Used for analyzing, cleaning, exploring, manuplication

# %% [markdown]
# # matplotlib

# %% [markdown]
# 1.Used for graph creation

# %% [markdown]
# # Numpy

# %% [markdown]
# 1.Used for array and mathematical operations

# %% [markdown]
# # Seaborn

# %% [markdown]
# 1.Used for graph creation and visualization

# %%
iData=pd.read_csv("Car_Data.csv")

# %% [markdown]
# iData=pd.read_csv("Car_Data.csv",dtype={'Manufacturer':str,'Model':str,'Horsepower':int}) # When we need to declare type of a column

# %%
iData.head(100) #used for read first 5 value and if you want you can pass more number in head(10)  ||| tail()- for last row
# Out:
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0   Acura          Integra                        16.919               16.36
# 1   Acura          TL                             39.384              19.875
# 2   Acura          CL                             14.114              18.225
# 3   Acura          RL                              8.588              29.725
# 4   Audi           A4                             20.397              22.255
# ..            ...                ...                 ...                 ...
# 95  Mercedes-Benz  SL-Class                        3.311                58.6
# 96  Mercedes-Benz  SLK                             7.998                   .
# 97  Mercedes-Benz  SLK230                          1.526                   .
# 98  Mercedes-Benz  CLK Coupe                      11.592                   .
# 99  Mercedes-Benz  CL500                           0.954                   .
#
# ...

# %%
iData.info()  # To get details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
iData.columns # To get all column info
# Out:
# Index(['Manufacturer', 'Model', 'Sales in thousands', '4-year resale value',
#        'Vehicle type', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency', 'Latest Launch'],
#       dtype='object')

# %%
pd.isnull(iData).sum().head(10) # TO get all null values count in column
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# dtype: int64

# %% [markdown]
# # Two Options to remove and modify null values

# %% [raw]
# 1.Fill null value with mean vaule

# %%
iData['Sales in thousands'].fillna(iData['Sales in thousands'].mean())
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64

# %% [markdown]
# 2.Remove all null values from csv

# %%
iData.dropna(inplace=True)

# %%
pd.isnull(iData).sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %% [markdown]
# # Analysis of data

# %%
iData['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Dodge            11
# Ford             11
# Toyota            9
# Chevrolet         9
# Mercedes-Benz     9
# Mitsubishi        7
# Nissan            7
# Chrysler          7
# Volvo             6
# Oldsmobile        6
# Lexus             6
# Mercury           6
# Pontiac           6
# Volkswagen        6
# Saturn            5
# Cadillac          5
# Honda             5
# Plymouth          4
# Acura             4
# Buick             4
# Audi              3
# Jeep              3
# Porsche           3
# Hyundai           3
# BMW               3
# Lincoln           3
# Saab              2
# Subaru            2
# Jaguar            1
# Infiniti          1
# Name: count, dtype: int64

# %%
ax=sb.countplot(x='Manufacturer',data=iData, hue='Vehicle type') 
sb.set(rc={'figure.figsize':(45,5)})

for barvalue in ax.containers:
     ax.bar_label(barvalue)

# %%
iData.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
iData['Engine size'].replace('.',0,inplace=True)

# %%
iData['Engine size'].fillna(0)
# Out:
# 0      1.8
# 1      3.2
# 2      3.2
# 3      3.5
# 4      1.8
#       ...
# 152    1.9
# 153    2.4
# 154    2.4
# 155    2.3
# 156    2.9
# Name: Engine size, Length: 157, dtype: object

# %%
iData['Engine size']=iData["Engine size"].astype("float")

# %%
iData['Engine size'].replace(0,iData['Engine size'].mean())
# Out:
# 0      1.8
# 1      3.2
# 2      3.2
# 3      3.5
# 4      1.8
#       ...
# 152    1.9
# 153    2.4
# 154    2.4
# 155    2.3
# 156    2.9
# Name: Engine size, Length: 157, dtype: float64

# %%
iData.replace('.',0,inplace=True)

# %%
iData.replace('',0,inplace=True)

# %%
iData['4-year resale value']=iData["4-year resale value"].astype("float")

# %%
iData['Price in thousands']=iData["Price in thousands"].astype("float")

# %%
iData['Horsepower']=iData["Horsepower"].astype("float")

# %%
iData['Wheelbase']=iData["Wheelbase"].astype("float")

# %%
iData['Width']=iData["Width"].astype("float")

# %%
iData['Curb weight']=iData["Curb weight"].astype("float")

# %%
iData['Fuel capacity']=iData["Fuel capacity"].astype("float")

# %%
iData['Fuel efficiency']=iData["4-year resale value"].astype("float")

# %%
iData['Length']=iData["Length"].astype("float")

# %%
iData.head(50)
# Out:
#      Manufacturer              Model  Sales in thousands  4-year resale value  \
# 0   Acura          Integra                        16.919               16.360
# 1   Acura          TL                             39.384               19.875
# 2   Acura          CL                             14.114               18.225
# 3   Acura          RL                              8.588               29.725
# 4   Audi           A4                             20.397               22.255
# 5   Audi           A6                             18.780               23.555
# 6   Audi           A8                              1.380               39.000
# 7   BMW            323i                           19.747                0.000
# 8   BMW            328i                            9.231               28.675
# 9   BMW            528i                           17.527               36.125
# 10  Buick          Century                        91.561               12.475
# ...

# %%
iData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    float64
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    float64
#  6   Engine size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb weight          157 non-null    float64
#  12  Fuel capacity        157 non-null    float64
#  13  Fuel efficiency      157 non-null    float64
#  14  Latest Launch        157 non-null    object
# ...

# %%
iData[iData["Vehicle type"].isin(['Car'])]
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 18   Cadillac       Escalade                       14.785
# 33   Chrysler       Town & Country                 53.480
# 40   Dodge          Ram Pickup                    227.061
# 41   Dodge          Ram Wagon                      16.767
# 42   Dodge          Ram Van                        31.038
# 43   Dodge          Dakota                        111.313
# 44   Dodge          Durango                       101.323
# 45   Dodge          Caravan                       181.749
# 52   Ford           Explorer                      276.747
# 53   Ford           Windstar                      155.787
# 54   Ford           Expedition                    125.338
# 55   Ford           Ranger                        220.650
# 56   Ford           F-Series                      540.561
# 59   Honda          CR-V                           73.203
# 60   Honda          Passport                       12.855
# ...

# %%
iData[iData['Price in thousands']>70.00]  # Filter more than
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 95   Mercedes-Benz  SL-Class                        3.311
# 99   Mercedes-Benz  CL500                           0.954
# 125  Porsche        Carrera Coupe                   1.280
# 126  Porsche        Carrera Cabriolet               1.866
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 95                58.600    Passenger               82.60          5.0
# 99                 0.000    Passenger               85.50          5.0
# 125               60.625    Passenger               71.02          3.4
# 126               67.550    Passenger               74.97          3.4
#
#      Horsepower  Wheelbase  Width  Length  Curb weight  Fuel capacity  \
# 95        302.0       99.0   71.3   177.1        4.125           21.1
# 99        302.0      113.6   73.1   196.6        4.115           23.2
# 125       300.0       92.6   69.5   174.5        3.032           17.0
# ...

# %%
iData[~ (iData['Price in thousands']>70.00)]  # Filter more than  70 and to remove record ~ "tilde" sine
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0    Acura          Integra                        16.919
# 1    Acura          TL                             39.384
# 2    Acura          CL                             14.114
# 3    Acura          RL                              8.588
# 4    Audi           A4                             20.397
# ..             ...                ...                 ...
# 152  Volvo          V40                             3.545
# 153  Volvo          S70                            15.245
# 154  Volvo          V70                            17.531
# 155  Volvo          C70                             3.493
# 156  Volvo          S80                            18.969
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0                 16.360    Passenger               21.50          1.8
# 1                 19.875    Passenger               28.40          3.2
# ...

# %%
sales_graph=iData.groupby(['Manufacturer'], as_index=False)['Sales in thousands'].sum().sort_values(by='Sales in thousands',ascending=True)
sb.set(rc={'figure.figsize' :(45,10)})
ax=sb.barplot(x='Manufacturer',y='Sales in thousands',data=sales_graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sales_graph=iData.groupby(['Manufacturer'], as_index=False)['Sales in thousands'].sum().sort_values(by='Sales in thousands',ascending=True)
#       2 sb.set(rc={'figure.figsize' :(45,10)})
#       3 ax=sb.barplot(x='Manufacturer',y='Sales in thousands',data=sales_graph)
#
# NameError: name 'iData' is not defined

# %%
Maximum sale amount is generated by ford

# %%
sales_graph=iData.groupby(['Manufacturer','Vehicle type'], as_index=False)['Sales in thousands'].sum().sort_values(by='Sales in thousands',ascending=True)
sb.set(rc={'figure.figsize' :(45,10)})
ax=sb.barplot(x='Manufacturer',y='Sales in thousands',data=sales_graph,hue='Vehicle type')

# %%
sales_graph=iData.groupby(['Manufacturer'], as_index=False)['Price in thousands'].sum().sort_values(by='Price in thousands',ascending=True)
sb.set(rc={'figure.figsize' :(45,10)})
ax=sb.barplot(x='Manufacturer',y='Price in thousands',data=sales_graph)

# %%
sales_graph=iData.groupby(['Horsepower'], as_index=False)['Sales in thousands'].sum().sort_values(by='Sales in thousands',ascending=False)
sb.set(rc={'figure.figsize' :(45,10)})
ax=sb.barplot(x='Horsepower',y='Sales in thousands',data=sales_graph)

# %%
150 Horsepower cars generate more sale

# %%
Maximum price is from Mercedes-benz
